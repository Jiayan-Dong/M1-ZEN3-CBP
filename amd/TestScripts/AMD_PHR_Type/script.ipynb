# %%
import pandas as pd 
import os

# %%
repeat0 = 20
repeat1 = 1000

# %%
final_df0 = pd.DataFrame()
for i in range(2,21):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df0[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df0.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 04:04:06 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:11 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:16 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:22 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:27 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:32 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:38 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:43 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:49 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:04:55 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:05:02 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:05:11 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:05:23 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:05:40 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:06:09 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:07:01 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:08:38 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:11:44 PM EST
# Experiment date and time: Fri 08 Dec 2023 04:17:48 PM EST
# <Axes: >

# %%
final_df1 = pd.DataFrame()
for i in range(2,8):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df1[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df1.plot()
