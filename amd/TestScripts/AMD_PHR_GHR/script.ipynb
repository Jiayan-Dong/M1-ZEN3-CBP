# %%
import pandas as pd 
import os

# %%
repeat0 = 20
repeat1 = 1000

# %%
# je
final_df0 = pd.DataFrame()
for i in range(4):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df0[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df0.plot()
# Out:
# Experiment date and time: Fri 22 Dec 2023 02:48:21 PM EST
# Experiment date and time: Fri 22 Dec 2023 02:51:49 PM EST
# Experiment date and time: Fri 22 Dec 2023 02:55:17 PM EST
# Experiment date and time: Fri 22 Dec 2023 02:58:46 PM EST
# <Axes: >

# %%
# je
final_df0 = pd.DataFrame()
for i in range(1):
    os.system("./run.sh 14")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df0[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df0.plot()
# Out:
# Experiment date and time: Fri 22 Dec 2023 03:14:48 PM EST
# <Axes: >

# %%
# je
final_df0 = pd.DataFrame()
for i in range(21):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df0[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df0.plot()
# Out:
# Experiment date and time: Fri 22 Dec 2023 05:23:55 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:26:23 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:28:53 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:31:22 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:33:51 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:36:20 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:38:49 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:41:19 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:43:51 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:46:28 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:49:14 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:52:12 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:55:34 PM EST
# Experiment date and time: Fri 22 Dec 2023 05:59:51 PM EST
# Experiment date and time: Fri 22 Dec 2023 06:05:36 PM EST
# Experiment date and time: Fri 22 Dec 2023 06:14:39 PM EST
# Experiment date and time: Fri 22 Dec 2023 06:29:38 PM EST
# Experiment date and time: Fri 22 Dec 2023 06:56:21 PM EST
# Experiment date and time: Fri 22 Dec 2023 07:46:08 PM EST
# Terminated
# Experiment date and time: Fri 22 Dec 2023 08:37:47 PM EST
# Terminated
# Experiment date and time: Fri 22 Dec 2023 08:38:01 PM EST
# Terminated
# <Axes: >

# %%
final_df0.iloc[:,:14].plot()
# Out:
# <Axes: >

# %%
final_df0.iloc[:,14:].plot()
# Out:
# <Axes: >

# %%
final_df0.iloc[:220:,18:].plot()
# Out:
# <Axes: >
