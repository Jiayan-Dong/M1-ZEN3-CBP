# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# %%sh
# ./run.sh
# Out:
# Experiment date and time: Fri 08 Dec 2023 05:06:12 AM EST

# %%
repeat0 = 20
repeat1 = 1000

# %%
data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
data["Clock"] = (data["Clock"]) / repeat1
data["BrRetired"] = data["BrRetired"] / repeat1
data["BrMispred"] = data["BrMispred"] / repeat1

# %%
new_df = data.groupby(data.index // repeat0).mean()

# %%
new_df['BrMispred'].plot()
# Out:
# <Axes: >

# %%
final_df = pd.DataFrame()
for i in range(2,9):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
# Out:
# Experiment date and time: Thu 07 Dec 2023 09:51:47 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:52:51 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:53:55 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:55:00 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:56:04 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:57:08 PM EST
# Experiment date and time: Thu 07 Dec 2023 09:58:12 PM EST

# %%
final_df.plot()
# Out:
# <Axes: >

# %%
final_df2 = pd.DataFrame()
for i in range(2,9):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df2[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
    final_df2.plot()
# Out:
# Experiment date and time: Thu 07 Dec 2023 10:02:26 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:03:30 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:04:34 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:05:38 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:06:42 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:07:46 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:08:50 PM EST

# %%
final_df3 = pd.DataFrame()
for i in range(2,9):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df3[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
    final_df3.plot()
# Out:
# Experiment date and time: Thu 07 Dec 2023 10:11:26 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:12:30 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:13:34 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:14:39 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:15:43 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:16:47 PM EST
# Experiment date and time: Thu 07 Dec 2023 10:17:51 PM EST

# %%
final_df4 = pd.DataFrame()
for i in range(2,9):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df4[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
    final_df4.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 05:06:26 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:07:30 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:08:35 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:09:40 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:10:45 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:11:50 AM EST
# Experiment date and time: Fri 08 Dec 2023 05:12:55 AM EST

# %%
final_df5 = pd.DataFrame()
for i in range(10,11):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df5[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
    final_df5.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 05:24:20 AM EST
