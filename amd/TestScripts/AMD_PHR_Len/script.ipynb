# %%
import pandas as pd 
import os

# %%
repeat0 = 20
repeat1 = 1000

# %%
# je
final_df0 = pd.DataFrame()
for i in range(4):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df0[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df0.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 12:24:09 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:25:24 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:26:40 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:27:55 PM EST
# <Axes: >

# %%
# jmp
final_df1 = pd.DataFrame()
for i in range(2):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df1[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df1.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 12:30:37 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:32:59 PM EST
# <Axes: >

# %%
# jne
final_df2 = pd.DataFrame()
for i in range(2):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df2[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df2.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 12:36:15 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:38:40 PM EST
# <Axes: >

# %%
# mixed
final_df3 = pd.DataFrame()
for i in range(2):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df3[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df3.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 12:41:43 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:44:12 PM EST
# <Axes: >

# %%
final_df3[1][116:122].plot()
# Out:
# <Axes: >

# %%
# jmp reg
final_df4 = pd.DataFrame()
for i in range(2):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df4[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df4.plot()
# Out:
# Experiment date and time: Fri 08 Dec 2023 12:54:03 PM EST
# Experiment date and time: Fri 08 Dec 2023 12:56:27 PM EST
# <Axes: >

# %%
# jne 1600
final_df2 = pd.DataFrame()
for i in range(2):
    os.system("./run.sh {}")

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df2[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df2.plot()
# Out:
# Experiment date and time: Fri 22 Dec 2023 12:43:04 PM EST
# Experiment date and time: Fri 22 Dec 2023 12:57:56 PM EST
# <Axes: >
