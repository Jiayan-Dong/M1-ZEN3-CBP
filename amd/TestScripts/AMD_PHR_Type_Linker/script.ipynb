# %%
import pandas as pd 
import os

# %%
repeat0 = 20
repeat1 = 4000

# %%
final_dfs = []
for i in range(2,13):
    final_df = pd.DataFrame()
    for j in range(2,13):
        os.system("./run.sh {} {}".format(i, j))

        data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
        data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
        data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
        data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
        data["Clock"] = (data["Clock"]) / repeat1
        data["BrRetired"] = data["BrRetired"] / repeat1
        data["BrMispred"] = data["BrMispred"] / repeat1
        final_df[j] = data.groupby(data.index // repeat0).mean()["BrMispred"]
    final_dfs.append(final_df)
# Out:
# Experiment date and time: Wed 24 Jan 2024 04:35:55 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:36:22 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:36:50 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:37:17 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:37:45 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:38:12 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:38:39 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:39:07 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:39:34 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:40:02 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:40:29 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:40:57 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:41:24 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:41:52 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:42:19 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:42:47 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:43:14 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:43:41 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:44:09 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:44:36 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:45:04 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:45:31 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:45:59 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:46:26 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:46:54 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:47:21 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:47:48 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:48:16 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:48:43 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:49:11 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:49:38 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:50:06 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:50:33 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:51:01 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:51:28 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:51:56 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:52:23 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:52:51 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:53:18 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:53:45 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:54:13 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:54:40 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:55:08 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:55:35 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:56:03 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:56:30 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:56:58 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:57:25 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:57:53 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:58:20 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:58:47 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:59:15 PM EST
# Experiment date and time: Wed 24 Jan 2024 04:59:42 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:00:10 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:00:37 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:01:05 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:01:32 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:01:59 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:02:27 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:02:54 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:03:22 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:03:49 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:04:17 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:04:44 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:05:11 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:05:39 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:06:07 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:06:34 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:07:01 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:07:29 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:07:56 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:08:24 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:08:51 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:09:19 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:09:47 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:10:14 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:10:42 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:11:09 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:11:37 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:12:04 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:12:32 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:12:59 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:13:26 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:13:54 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:14:21 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:14:49 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:15:16 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:15:44 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:16:12 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:16:39 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:17:07 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:17:34 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:18:02 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:18:30 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:18:57 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:19:25 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:19:52 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:20:20 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:20:48 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:21:15 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:21:43 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:22:11 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:22:39 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:23:06 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:23:34 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:24:02 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:24:29 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:24:57 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:25:25 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:25:53 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:26:21 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:26:49 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:27:17 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:27:45 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:28:13 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:28:41 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:29:09 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:29:37 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:30:05 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:30:33 PM EST
# Experiment date and time: Wed 24 Jan 2024 05:31:01 PM EST

# %%
for i, df in enumerate(final_dfs, 2):
    df.plot(title="{}".format(i))
    df.to_pickle('./script1/{}.pkl'.format(i))

# %%
final_dfs[2]
# Out:
#           2         3         4         5         6         7         8   \
# 0   0.272587  0.271225  0.000200  0.000200  0.000125  0.000113  0.000175
# 1   0.270113  0.267000  0.000200  0.000163  0.000087  0.000100  0.000137
# 9   0.000113  0.000113  0.000150  0.498412
# 10  0.000125  0.000163  0.000137  0.500800
# 11  0.000137  0.000100  0.000113  0.499488
# 12  0.000200  0.000113  0.000125  0.500287
# 13  0.000163  0.000137  0.000163  0.499850
# 14  0.000113  0.000113  0.000200  0.502587
# 15  0.000200  0.000163  0.000137  0.499600
# 16  0.000113  0.000125  0.000163  0.501312
# 17  0.000150  0.000100  0.000113  0.500312
# 18  0.000100  0.000113  0.000113  0.497425
# 19  0.000875  0.001463  0.001587  0.499750
# 20  0.502350  0.499250  0.500938  0.500825
# 21  0.501950  0.497800  0.500100  0.501025
# 22  0.499538  0.497475  0.501450  0.498763
# 23  0.500337  0.498437  0.497825  0.500088
# 24  0.501062  0.499238  0.500275  0.499225
# 25  0.501075  0.497675  0.500850  0.496825
# 26  0.500625  0.499488  0.500500  0.500737
# 27  0.500788  0.499312  0.499512  0.502175
# 28  0.500200  0.496975  0.498113  0.499362
# 29  0.500287  0.499913  0.500125  0.498600
# 30  0.505375  0.499338  0.496387  0.501000

# %%
for i, df in enumerate(final_dfs, 2):
    df[16:22].plot(title="{}".format(i))

# %%
final_df0[110:130].plot()
# Out:
# <Axes: >

# %%
final_df1 = pd.DataFrame()
for i in range(20,21):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df1[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df1.plot()
# Out:
# Experiment date and time: Fri 19 Jan 2024 04:19:21 PM EST
# <Axes: >

# %%
final_df1[110:130].plot()
# Out:
# <Axes: >

# %%
final_df2 = pd.DataFrame()
for i in range(20,21):
    os.system("./run.sh {}".format(i))

    data = pd.read_csv("results.csv", comment='#', delim_whitespace=True)
    data["Clock"] = pd.to_numeric(data["Clock"],errors='coerce')
    data["BrRetired"] = pd.to_numeric(data["BrRetired"],errors='coerce')
    data["BrMispred"] = pd.to_numeric(data["BrMispred"],errors='coerce')
    data["Clock"] = (data["Clock"]) / repeat1
    data["BrRetired"] = data["BrRetired"] / repeat1
    data["BrMispred"] = data["BrMispred"] / repeat1
    final_df2[i] = data.groupby(data.index // repeat0).mean()["BrMispred"]
final_df2.plot()
# Out:
# Experiment date and time: Fri 19 Jan 2024 04:22:36 PM EST
# <Axes: >

# %%
final_df2[110:130].plot()
# Out:
# <Axes: >
